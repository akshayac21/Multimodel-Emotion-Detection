# %%
# =========================================================
# 1. IMPORTS
# =========================================================
import os
import glob
import numpy as np
import librosa
import soundfile
import tensorflow as tf

from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, BatchNormalization,
    Bidirectional, LSTM, Dense, Dropout
)
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
# Out:
# 2025-12-26 08:44:30.012906: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766738670.426608      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766738670.542220      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766738671.558335      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766738671.558379      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766738671.558388      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766738671.558391      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
# =========================================================
# 2. CONFIGURATION (UNCHANGED)
# =========================================================
INPUT_DIR = "/kaggle/input"

EMOTIONS = {
    '01': 'neutral',
    '02': 'calm',
    '03': 'happy',
    '04': 'sad',
    '05': 'angry',
    '06': 'fearful',
    '07': 'disgust',
    '08': 'surprised'
}

OBSERVED_EMOTIONS = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']

# %%
# =========================================================
# 3. FEATURE EXTRACTION (MFCC TIME-SERIES)
# =========================================================
def extract_feature(file_name, n_mfcc=40):
    """
    Extract MFCC features as a time-series for CNN + BiLSTM
    Output shape: (time_steps, n_mfcc)
    """
    try:
        with soundfile.SoundFile(file_name) as sound_file:
            X = sound_file.read(dtype="float32")
            sample_rate = sound_file.samplerate

            # Convert stereo to mono
            if len(X.shape) > 1:
                X = np.mean(X, axis=1)

            mfccs = librosa.feature.mfcc(
                y=X,
                sr=sample_rate,
                n_mfcc=n_mfcc
            )

            return mfccs.T  # (time, features)

    except Exception:
        return None

# %%
# =========================================================
# 4. DATA LOADING (SAME AS YOUR ORIGINAL LOGIC)
# =========================================================
def load_data(test_size=0.2):
    x, y = [], []

    # Recursively find wav files
    wav_files = glob.glob(os.path.join(INPUT_DIR, "**/*.wav"), recursive=True)

    if not wav_files:
        print("❌ Error: No .wav files found in dataset")
        return None, None, None, None

    print(f"Found {len(wav_files)} files. Extracting features...")

    for file in wav_files:
        file_name = os.path.basename(file)
        parts = file_name.split("-")

        # RAVDESS emotion code is 3rd field
        if len(parts) < 3:
            continue

        emotion_code = parts[2]
        emotion = EMOTIONS.get(emotion_code)

        if emotion in OBSERVED_EMOTIONS:
            feature = extract_feature(file)
            if feature is not None:
                x.append(feature)
                y.append(OBSERVED_EMOTIONS.index(emotion))

    print(f"Extraction complete. Dataset size: {len(x)} samples")

    # Pad sequences for CNN + BiLSTM
    x = pad_sequences(x, padding="post", dtype="float32")

    # One-hot encode labels
    y = to_categorical(y, num_classes=len(OBSERVED_EMOTIONS))

    return train_test_split(x, y, test_size=test_size, random_state=9)

# %%
# =========================================================
# 5. LOAD DATA
# =========================================================
x_train, x_test, y_train, y_test = load_data()

if x_train is None:
    raise RuntimeError("Dataset loading failed")

print("Training data shape:", x_train.shape)
print("Testing data shape :", x_test.shape)
# Out:
# Found 2880 files. Extracting features...
# Extraction complete. Dataset size: 2112 samples
# Training data shape: (1689, 479, 40)
# Testing data shape : (423, 479, 40)

# %%
# =========================================================
# 6. CNN + BiLSTM MODEL
# =========================================================
model = Sequential([

    Conv1D(128, kernel_size=5, activation="relu",
           input_shape=(x_train.shape[1], x_train.shape[2])),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(256, kernel_size=5, activation="relu"),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Bidirectional(LSTM(128, return_sequences=True)),
    Bidirectional(LSTM(64)),

    Dense(128, activation="relu"),
    Dropout(0.4),

    Dense(len(OBSERVED_EMOTIONS), activation="softmax")
])

model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-12-26 08:46:42.133973: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 475, 128)       │        25,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 475, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 237, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 233, 256)       │       164,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 233, 256)       │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 116, 256)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 116, 256)       │       394,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 128)            │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 767,238 (2.93 MB)
#  Trainable params: 766,470 (2.92 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
# =========================================================
# 7. TRAINING
# =========================================================
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True
)

history = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 36s
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 510ms/step - accuracy: 0.9365 - loss: 0.1928 - val_accuracy: 0.8345 - val_loss: 0.5971
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 508ms/step - accuracy: 0.9348 - loss: 0.1898 - val_accuracy: 0.8369 - val_loss: 0.6581
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 507ms/step - accuracy: 0.9323 - loss: 0.2220 - val_accuracy: 0.9196 - val_loss: 0.2705
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 509ms/step - accuracy: 0.9760 - loss: 0.0867 - val_accuracy: 0.9125 - val_loss: 0.4025
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 521ms/step - accuracy: 0.9769 - loss: 0.0699 - val_accuracy: 0.9243 - val_loss: 0.2995
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 508ms/step - accuracy: 0.9741 - loss: 0.0817 - val_accuracy: 0.8629 - val_loss: 0.4769
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 508ms/step - accuracy: 0.9546 - loss: 0.1463 - val_accuracy: 0.8203 - val_loss: 0.6372
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 508ms/step - accuracy: 0.9611 - loss: 0.1232 - val_accuracy: 0.8558 - val_loss: 0.5622
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 521ms/step - accuracy: 0.9759 - loss: 0.0701 - val_accuracy: 0.9031 - val_loss: 0.3459
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 521ms/step - accuracy: 0.9737 - loss: 0.0795 - val_accuracy: 0.9149 - val_loss: 0.4079
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 509ms/step - accuracy: 0.9914 - loss: 0.0321 - val_accuracy: 0.9362 - val_loss: 0.2654
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 521ms/step - accuracy: 0.9946 - loss: 0.0206 - val_accuracy: 0.8983 - val_loss: 0.5175
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 509ms/step - accuracy: 0.9839 - loss: 0.0629 - val_accuracy: 0.9362 - val_loss: 0.3034
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 509ms/step - accuracy: 0.9805 - loss: 0.0506 - val_accuracy: 0.9173 - val_loss: 0.3438
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 510ms/step - accuracy: 0.9838 - loss: 0.0549 - val_accuracy: 0.9173 - val_loss: 0.3223
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 514ms/step - accuracy: 0.9778 - loss: 0.0778 - val_accuracy: 0.9149 - val_loss: 0.4203
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 515ms/step - accuracy: 0.9861 - loss: 0.0583 - val_accuracy: 0.9433 - val_loss: 0.2514
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 527ms/step - accuracy: 0.9948 - loss: 0.0272 - val_accuracy: 0.9196 - val_loss: 0.4064
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 511ms/step - accuracy: 0.9898 - loss: 0.0322 - val_accuracy: 0.8771 - val_loss: 0.5282
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 518ms/step - accuracy: 0.9797 - loss: 0.0715 - val_accuracy: 0.8274 - val_loss: 0.7758
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 519ms/step - accuracy: 0.9684 - loss: 0.0998 - val_accuracy: 0.7920 - val_loss: 0.9087
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 516ms/step - accuracy: 0.9613 - loss: 0.1515 - val_accuracy: 0.8085 - val_loss: 0.6437
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 41s 515ms/step - accuracy: 0.9720 - loss: 0.0995 - val_accuracy: 0.9007 - val_loss: 0.3443
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 535ms/step - accuracy: 0.9910 - loss: 0.0313 - val_accuracy: 0.8913 - val_loss: 0.4035
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 514ms/step - accuracy: 0.9842 - loss: 0.0501 - val_accuracy: 0.9102 - val_loss: 0.3952
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 27s 512ms/step - accuracy: 0.9865 - loss: 0.0360 - val_accuracy: 0.9054 - val_loss: 0.3730
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 526ms/step - accuracy: 0.9874 - loss: 0.0408 - val_accuracy: 0.9031 - val_loss: 0.4618

# %%
# =========================================================
# 8. EVALUATION
# =========================================================
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"\n✅ CNN + BiLSTM Accuracy: {accuracy * 100:.2f}%")
# Out:
# ✅ CNN + BiLSTM Accuracy: 94.33%

# %%
# =========================================================
# 9. SAVE MODEL
# =========================================================
MODEL_PATH = "/kaggle/working/voice_emotion_cnn_bilstm.h5"
model.save(MODEL_PATH)

print(f"\n✅ Model saved to: {MODEL_PATH}")
print("⚠️ Download this file from the Kaggle Output section")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model saved to: /kaggle/working/voice_emotion_cnn_bilstm.h5
# ⚠️ Download this file from the Kaggle Output section
